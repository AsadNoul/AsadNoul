# %% [markdown]
# <a href="https://colab.research.google.com/github/AsadNoul/AsadNoul/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 56.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.18.0
#     Uninstalling pygit2-1.18.0:
#       Successfully uninstalled pygit2-1.18.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Counting objects: 100% (1361/1361), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 6725 (delta 1302), reused 1210 (delta 1210), pack-reused 5364 (from 1)
# Receiving objects: 100% (6725/6725), 33.19 MiB | 26.24 MiB/s, done.
# Resolving deltas: 100% (3929/3929), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# ...
